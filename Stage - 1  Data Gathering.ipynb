# %%
import tweepy
import webbrowser
import time

# %%
CONSUMER_KEY = "dl5cr1RBK1tRZZUWbIgNRe1vJ"
CONSUMER_SECRET = "O0Ryv7Gbbzu4YdSxmAZl987SO38A8jn6jrzoiOKruao7Ar0Rdw"

# %%
callback_uri = 'oob'

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET,callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
# Out:
# True

# %%
user_print_input = input("What is the pin value? ")
# Out:
# What is the pin value? 4273273

# %%
user_print_input
# Out:
# '4273273'

# %%
auth.get_access_token(user_print_input)
# Out:
# ('1464089781290340352-IqZtQJx8kjbdfAVB0S442VYj1zgZHT',
#  'oMaF2Lmq3lVSTg7HD18SGZtA7HPJZxZzY3YtF58z4rmG4')

# %%
print(auth.access_token)
# Out:
# 1464089781290340352-IqZtQJx8kjbdfAVB0S442VYj1zgZHT

# %%
print(auth.access_token_secret)
# Out:
# oMaF2Lmq3lVSTg7HD18SGZtA7HPJZxZzY3YtF58z4rmG4

# %%
api = tweepy.API(auth)

# %%
import pandas as pd

# %%
query='news'
max_tweets = 800
searched_tweets=[status for  status in tweepy.Cursor(api.search_tweets, q=query,lang="en").items(max_tweets)]

# %%
searched_tweets[50]
# Out:
# Status(_api=<tweepy.api.API object at 0x0000027525564790>, _json={'created_at': 'Thu Dec 02 09:20:02 +0000 2021', 'id': 1466336346033774595, 'id_str': '1466336346033774595', 'text': 'Bosses cancel Christmas parties and tell workers to stay home\nhttps://t.co/owjs7WitGi https://t.co/oCkBcFGtUY', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/owjs7WitGi', 'expanded_url': 'https://bmmagazine.co.uk/news/bosses-cancel-christmas-parties-and-tell-workers-to-stay-home/', 'display_url': 'bmmagazine.co.uk/news/bosses-ca…', 'indices': [62, 85]}], 'media': [{'id': 1466336344230219779, 'id_str': '1466336344230219779', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/FFl5ItcWUAMngq1.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FFl5ItcWUAMngq1.jpg', 'url': 'https://t.co/oCkBcFGtUY', 'display_url': 'pic.twitter.com/oCkBcFGtUY', 'expanded_url': 'https://twitter.com/BizMattersmag/status/1466336346033774595/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1365, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 800, 'resize': 'fit'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1466336344230219779, 'id_str': '1466336344230219779', 'indices': [86, 109], 'media_url': 'http://pbs.twimg.com/media/FFl5ItcWUAMngq1.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FFl5ItcWUAMngq1.jpg', 'url': 'https://t.co/oCkBcFGtUY', 'display_url': 'pic.twitter.com/oCkBcFGtUY', 'expanded_url': 'https://twitter.com/BizMattersmag/status/1466336346033774595/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1365, 'resize': 'fit'}, 'medium': {'w': 1200, 'h': 800, 'resize': 'fit'}, 'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 17714548, 'id_str': '17714548', 'name': 'Business Matters', 'screen_name': 'BizMattersmag', 'location': 'UK', 'description': 'Business Matters: UKs largest business magazine for entrepreneurs & owners of Small & Medium sized businesses. In print, on your tablet, on the move, online', 'url': 'https://t.co/QIsF720UaT', 'entities': {'url': {'urls': [{'url': 'https://t.co/QIsF720UaT', 'expanded_url': 'https://www.bmmagazine.co.uk', 'display_url': 'bmmagazine.co.uk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 36162, 'friends_count': 350, 'listed_count': 689, 'created_at': 'Fri Nov 28 17:56:26 +0000 2008', 'favourites_count': 157, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 50571, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1418126263798140931/1D55vdJZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1418126263798140931/1D55vdJZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17714548/1626942624', 'profile_link_color': '403E40', 'profile_sidebar_border_color': '1C63D6', 'profile_sidebar_fill_color': 'BAE5F5', 'profile_text_color': '784A00', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', ' ...

# %%
columns = set()
allowed_types = [str,int]
tweets_data = []

for status in searched_tweets:
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
            
        if v_type != None:
            
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]   
                columns.add(k)
    tweets_data.append(single_tweet_data)

# %%
header_cols = list(columns)

# %%
header_cols
# Out:
# ['retweet_count',
#  'lang',
#  'id_str',
#  'text',
#  'in_reply_to_screen_name',
#  'source',
#  'in_reply_to_status_id_str',
#  'quoted_status_id',
#  'id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_user_id',
#  'favorite_count',
#  'in_reply_to_status_id',
#  'quoted_status_id_str',
#  'source_url']

# %%
tweets_data
# Out:
# [{'id': 1466336359501598721,
#   'id_str': '1466336359501598721',
#   'text': 'RT @LaysPhilippines: Great news! Lay’s is now “100% Plastic Neutral”!*\n\nThis means for every pack you buy an equal amount of plastic waste…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 318,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336358700437514,
#   'id_str': '1466336358700437514',
#   'text': 'RT @livemint: India to initially introduce #ZyCoV-D Covid vaccine in 7 states. \n\nDetails here:\nhttps://t.co/RPckS4UM8i https://t.co/W6VjAxm…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336358478323714,
#   'id_str': '1466336358478323714',
#   'text': 'RT @HallamHRI: 🗣Join us for our next SHU internal @HallamHRI #Methodology Seminar on Wednesday 08/12 at 1:45pm. Our confirmed speaker is:…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336357337354240,
#   'id_str': '1466336357337354240',
#   'text': 'RT @thetrialfiles: TRIAL TO TRACK |\n\nIt’s here! https://t.co/qpi7FF0pH2',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336357224267778,
#   'id_str': '1466336357224267778',
#   'text': 'Triple-jabbed Israeli doctor believes he caught Omicron in London on 23 November https://t.co/9NM9oPE3sm',
#   'source': 'SocialFlow',
#   'source_url': 'http://www.socialflow.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336357094207488,
#   'id_str': '1466336357094207488',
#   'text': 'RT @financialombuds: We’ve published today an action plan to change and improve the organisation to provide the best service for our custom…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336356901265409,
#   'id_str': '1466336356901265409',
#   'text': "RT @TheSinanKose: Tell me again how I'm supposed to fear a British equivalent of Fox News taking the BBC's place?",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'quoted_status_id': 1466312656667779078,
#   'quoted_status_id_str': '1466312656667779078',
#   'retweet_count': 18,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336356699979778,
#   'id_str': '1466336356699979778',
#   'text': 'RT @Jingo82943256: Breaking News\n\n"Think Of How To Secure The Unconditional Release Of @MaziNnamdiKanu, Not How To Stop Sit-At-Home" ~ Rev.…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 13,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336356301295617,
#   'id_str': '1466336356301295617',
#   'text': 'RT @lili4lisaa: I hope 2022 is a year full of good news and blessings 🤞🏻🍀\n\nI vote #mamavote #lisa',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336356146290696,
#   'id_str': '1466336356146290696',
#   'text': 'The 26-year-old died at the scene and his little brother was rushed to hospital\n\nhttps://t.co/mzIkcF4LJ1',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336356074811392,
#   'id_str': '1466336356074811392',
#   'text': 'RT @KenRoth: On Mar 14, Myanmar security forces deliberately "kettled" protesters: surrounding them, trapping them, and killing them w/ mil…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 34,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336355982606337,
#   'id_str': '1466336355982606337',
#   'text': 'QSO Today Virtual Ham Expo - Call for Speakers and Presentations: The QSO Today Virtual Ham Expo will return on the… https://t.co/e1TpWsdHFF',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336355600977925,
#   'id_str': '1466336355600977925',
#   'text': 'RT @BDliveSA: BREAKING NEWS: Court orders fresh decision on how to hold Ramaphosa vote of no confidence https://t.co/aPx6R7oSpS',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336355424739329,
#   'id_str': '1466336355424739329',
#   'text': "What channel is Cowboys vs. Saints on today? Schedule, time for NFL 'Thursday Night Football' in Week 13 – NFL News… https://t.co/yeNtSSRPxY",
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336355085127683,
#   'id_str': '1466336355085127683',
#   'text': '@CryptoZyte_News @trace_network During the 2021 I got scammed a few times, rugs, exit scams etc. - how can we inves… https://t.co/PoaDx93yVV',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'in_reply_to_status_id': 1466334704475336708,
#   'in_reply_to_status_id_str': '1466334704475336708',
#   'in_reply_to_user_id': 1321953728199487488,
#   'in_reply_to_user_id_str': '1321953728199487488',
#   'in_reply_to_screen_name': 'CryptoZyte_News',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336355030552578,
#   'id_str': '1466336355030552578',
#   'text': 'Chicago drops its lawsuit against police union in fight over vaccine mandate for city employees https://t.co/49guIURRPd',
#   'source': 'SocialFlow',
#   'source_url': 'http://www.socialflow.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336353453551629,
#   'id_str': '1466336353453551629',
#   'text': 'RT @wildhyperbole: Macron calls Bojo ‘un clown’ who creates phoney wars to mask Brexit chaos - “In private, he says he is sorry to act this…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336353134645248,
#   'id_str': '1466336353134645248',
#   'text': 'Suffolk Coastal MP Therese Coffey has warned people to avoid "snogging under the mistletoe" at Christmas parties to… https://t.co/3CGVxyAOZz',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336352992178178,
#   'id_str': '1466336352992178178',
#   'text': 'Macron accused of sowing division with comment over Brexit deal\xa0 https://t.co/3gbKkJCVTM via @MailOnline',
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336352853766151,
#   'id_str': '1466336352853766151',
#   'text': 'Four groups at Arizona State University want Kyle Rittenhouse, who described himself during court proceedings as a… https://t.co/tIUQ7HNoNg',
#   'source': 'SocialFlow',
#   'source_url': 'http://www.socialflow.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336352237240320,
#   'id_str': '1466336352237240320',
#   'text': 'The UNHCR has described Britain\'s new immigration legislation as "a recipe for mental and physical ill health, soci… https://t.co/34Z3iFsWdU',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336351939407873,
#   'id_str': '1466336351939407873',
#   'text': 'RT @GuitarWorld: Steel Panther are still searching for a new bassist – and they need your help to narrow the field of candidates https://t.…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336351863795717,
#   'id_str': '1466336351863795717',
#   'text': 'RT @Myvoice03: Exactly my point is this. seiyirathellam senjitu ithu task ku sonna athu wrong . either accept that we did for news trp othe…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'quoted_status_id': 1466331560072802307,
#   'quoted_status_id_str': '1466331560072802307',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336351561805826,
#   'id_str': '1466336351561805826',
#   'text': 'RT @andreasharsono: Japan officially condemns the Myanmar coup while it slowly normalizes contact with the military junta. Instead of playi…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 124,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350911676418,
#   'id_str': '1466336350911676418',
#   'text': 'RT @AnkitPr84927630: Lalantop news .always stand for students. \n#JusticeForRailwayStudents https://t.co/fGcPwSoJpB',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 16,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350899040264,
#   'id_str': '1466336350899040264',
#   'text': 'A Customer Discovered Their $350 Lego Set Was Missing Pieces. The Company’s Response Was Brilliant https://t.co/uSZOX3n2ER',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350853025793,
#   'id_str': '1466336350853025793',
#   'text': "RT @IsntTony105: Breaking News: I've painted my bathroom, put up a new shower curtain and installed a first aid kit in the cupboard. Under…",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 612,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350819467268,
#   'id_str': '1466336350819467268',
#   'text': "RT @Dr_Ellie: COVID-19: Most Omicron cases are 'mild' and there's no evidence to suggest vaccines may be less effective against the variant…",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 1132,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350647558146,
#   'id_str': '1466336350647558146',
#   'text': "Covid-19 pandemic: Bengal logs 12 more deaths, 668 fresh cases The state's Covid tally also mounted to 1,616,751… https://t.co/ZDCFT7Zkbm",
#   'source': 'MarketsCafe',
#   'source_url': 'https://marketscafe.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350475632644,
#   'id_str': '1466336350475632644',
#   'text': 'RT @Amaka_Ekwo: There is news that Mazi Nnamdi Kanu will be arraigned at the Federal High Court Abuja tomorrow, the 2nd of December 2021.…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 331,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350425149443,
#   'id_str': '1466336350425149443',
#   'text': 'ARISS contact is scheduled for students at Hino Elementary School and Canna Project-Canna School Contact Team Suzak… https://t.co/HR61vjPJ5A',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350387388418,
#   'id_str': '1466336350387388418',
#   'text': 'RT @Suparna_Singh: Good morning. Our big news with dream partner @taboola  🙏https://t.co/caIZT2Bxi6',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350345572352,
#   'id_str': '1466336350345572352',
#   'text': "RT @THREAT_CS: (1/2) Some exciting news: IEMW is my last event as Head Coach as I'll move into a role as Technical Director of all our CS e…",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 14,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350303576064,
#   'id_str': '1466336350303576064',
#   'text': 'RT @arabnews: #Ethiopia risks descending into sectarian violence and experiencing chaotic #Kabul-style exodus if the year-long conflict spr…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350257385472,
#   'id_str': '1466336350257385472',
#   'text': 'GOP Wayne County election official in 2020 ballot dispute dies from COVID-19 https://t.co/obQiLCYuvK',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336350018412546,
#   'id_str': '1466336350018412546',
#   'text': 'RT @mattletiss7: Why isn’t this on the bbc news https://t.co/AvnbMV4oS6',
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'retweet_count': 285,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349963829253,
#   'id_str': '1466336349963829253',
#   'text': '"Students call for tuition fees refund as lecturers\' union begins three-day strike" https://t.co/EHNkPsV8un https://t.co/Jb3KDqNq6F',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349867454468,
#   'id_str': '1466336349867454468',
#   'text': 'RT @DanRebellato: To sum up, Jacob Rees-Mogg is under investigation for not declaring £6m in loans; Matt Hancock may have misled the House…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 784,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349859024901,
#   'id_str': '1466336349859024901',
#   'text': 'RT @DrJohnB2: https://t.co/RTd49MTWv6\n- "Almost 9,300 more people than usual have died from conditions unrelated to coronavirus since July"…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 48,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349582237703,
#   'id_str': '1466336349582237703',
#   'text': 'RT @toadmeister: ‘Sigh of relief in South African as Omicron appears to be super-mild mutation with Covid death rate not jumping.’ https://…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 53,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349565304835,
#   'id_str': '1466336349565304835',
#   'text': 'Aloca, Ivanhoe, Barrick Gold heads to speak at Riyadh mineral summit in January\nArab News\nhttps://t.co/9UCuxyW7r6',
#   'source': 'SourcesEh',
#   'source_url': 'https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349359775752,
#   'id_str': '1466336349359775752',
#   'text': '$BTC.X $ETH.X $XRP.X Elon Musk Criticizes Web3 Technology, Diminishing "2010s-Like Returns" https://t.co/sDtleqsYN2 https://t.co/Cv3EpDx1E3',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336349137498117,
#   'id_str': '1466336349137498117',
#   'text': 'Elon Musk Criticizes Web3 Technology, Diminishing "2010s-Like Returns" https://t.co/0eC9cLcW4I',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336348990754816,
#   'id_str': '1466336348990754816',
#   'text': 'How Sokoto, Lagos residents are tackling sexual, gender-based violence  https://t.co/EoEDSn2cko',
#   'source': 'SocialManagerr',
#   'source_url': 'https://syndpub.enew.co/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336348873236483,
#   'id_str': '1466336348873236483',
#   'text': "Change in the Composition of Kamux’s Shareholders' Nomination Board https://t.co/LF3kSylW3H",
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336348722253833,
#   'id_str': '1466336348722253833',
#   'text': 'LOT Polish Airlines nears order for 50+ A220/E2s https://t.co/Zeo4xVLU5b',
#   'source': 'dlvr.it',
#   'source_url': 'https://dlvrit.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336347774324741,
#   'id_str': '1466336347774324741',
#   'text': 'Create An Emergency Response Unit In Every Region To Tackle Diseases -A/R Minister .... https://t.co/PUReqSJLzt',
#   'source': 'Peace FM Online',
#   'source_url': 'http://www.peacefmonline.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336346675548160,
#   'id_str': '1466336346675548160',
#   'text': 'We are excited to announce that the call is now open for BU students to apply to the new Turing Scheme funded train… https://t.co/x31xS2uZYP',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336346386186240,
#   'id_str': '1466336346386186240',
#   'text': "Nintendo Has Updated Its Switch Online App To Version 1.14.0, See What's Included https://t.co/GIyZfljknS #Repost… https://t.co/OHJJ92BpH6",
#   'source': 'Nlife CMS',
#   'source_url': 'https://nlife.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336346327470081,
#   'id_str': '1466336346327470081',
#   'text': 'RT @AlasdairMack66: “Failures in the immigration &amp; asylum system cannot be remedied by harsher penalties &amp; more dangerous enforcement actio…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 17,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336346033774595,
#   'id_str': '1466336346033774595',
#   'text': 'Bosses cancel Christmas parties and tell workers to stay home\nhttps://t.co/owjs7WitGi https://t.co/oCkBcFGtUY',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345928908803,
#   'id_str': '1466336345928908803',
#   'text': 'New body worn camera (BWC) technology for #AMSA frontline staff is on the way! Benefits for the maritime industry i… https://t.co/Cf1fD35IRq',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345710804994,
#   'id_str': '1466336345710804994',
#   'text': 'Church News Ireland - December 2\nImage of the day - Advent Light\nPlague of drugs is raging out of control,’ Dublin… https://t.co/A1SXQ2Xw6r',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345698222082,
#   'id_str': '1466336345698222082',
#   'text': 'https://t.co/HAoCdlOzcI Brent Oil eyes a slide to the August low at $64.60 – SocGen',
#   'source': 'FxBookLTTG',
#   'source_url': 'https://www.fxbook.org',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345551474688,
#   'id_str': '1466336345551474688',
#   'text': 'RT @FraserNelson: There are about a million undocumented migrants in Britain - our countrymen, neighbours, perhaps even  colleagues - and a…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 16,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345274658819,
#   'id_str': '1466336345274658819',
#   'text': 'PFEW Chair slams Government on pay freeze as survey outlines damage to psychological wellbeing of colleagues:… https://t.co/zKPjd6Jo0q',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336345220079623,
#   'id_str': '1466336345220079623',
#   'text': 'Glen Moray launches new Manzanilla Sherry finished limited edition bottling: https://t.co/iehX1mFA1E @GlenMorayDist… https://t.co/o2KSltWJHy',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344855166982,
#   'id_str': '1466336344855166982',
#   'text': 'RT @D2X__: GOOD NEWS!!! I made it on my first Spotify Editorial playlist today! God is good!',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 40,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344448327683,
#   'id_str': '1466336344448327683',
#   'text': 'https://t.co/BqebZ6Hq5J WTI Price Analysis: Awaits OPEC+ decision while within a symmetrical triangle',
#   'source': 'FxBookLTTG',
#   'source_url': 'https://www.fxbook.org',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344444223488,
#   'id_str': '1466336344444223488',
#   'text': 'Man stabbed police officer with pen and punched another in the eye https://t.co/AXaUUzVpVC',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344314155010,
#   'id_str': '1466336344314155010',
#   'text': 'Irish Ferries has announced they will be adding a third ferry to the Dover to Calais route... https://t.co/kyXLuSoP2N',
#   'source': 'SocialFlow',
#   'source_url': 'http://www.socialflow.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344204931080,
#   'id_str': '1466336344204931080',
#   'text': 'RT @sridevisreedhar: #ChiyaanVikram and @beemji film confirmed, to start rolling soon!\n\nMORE: https://t.co/v81hhj3sJD https://t.co/d5OgfFX2…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 80,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336344012210181,
#   'id_str': '1466336344012210181',
#   'text': "IPPN President Brian O'Doherty and member Enda McGorman on mask-wearing in primary schools. \n\nPrincipals say mask w… https://t.co/cDnVtxHtTE",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336343617945602,
#   'id_str': '1466336343617945602',
#   'text': 'Electric cars already threatened by poor charging infrastructure warns SMMT\n\nhttps://t.co/rkKNcN0h6t\n\n#Automotive… https://t.co/LSx4SfVoCY',
#   'source': 'ContentCal Studio',
#   'source_url': 'https://www.contentcal.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336343559127047,
#   'id_str': '1466336343559127047',
#   'text': 'Feilden Clegg Bradley completes Warwick arts building | Seven-storey scheme centred around timber staircase… https://t.co/CZBM1vQpgG',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336343403991040,
#   'id_str': '1466336343403991040',
#   'text': '“#AI will be crucial for the efficient #management of our #urbanspaces, and making them #healthier, #safer, and mor… https://t.co/bfb4xqnjVe',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336343202615299,
#   'id_str': '1466336343202615299',
#   'text': 'DfE teacher training plans: What teachers need to know | TES https://t.co/PjZy27DJ5l',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336343122923522,
#   'id_str': '1466336343122923522',
#   'text': 'RT @brightonargus: A councillor has defended spending four months at his French holiday home as #Brighton battled Covid - saying it was "th…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336342959439882,
#   'id_str': '1466336342959439882',
#   'text': 'AJ Bell sees ‘significant’ chance for growth on back of bumper results\n\nhttps://t.co/YBK1tLIo0S',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336342930079745,
#   'id_str': '1466336342930079745',
#   'text': '#Sugar - the sweet temptation 🍬 Sugar is found in many delicious foods. In a recent test, a total of 45 different w… https://t.co/kTeMSgZvuE',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336342749573121,
#   'id_str': '1466336342749573121',
#   'text': 'General Department of Customs and Excise Releases Notice on Car Taxation https://t.co/8aEDkaP1op',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336341734612992,
#   'id_str': '1466336341734612992',
#   'text': 'RT @physorg_com: Island turns into open-air lab for tech-savvy volcanologists https://t.co/J7pSWw8UjQ',
#   'source': 'Science X Status Updates',
#   'source_url': 'https://sciencex.com/',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336340778307590,
#   'id_str': '1466336340778307590',
#   'text': 'Island turns into open-air lab for tech-savvy volcanologists https://t.co/J7pSWw8UjQ',
#   'source': 'Science X Status Updates',
#   'source_url': 'https://sciencex.com/',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336340421660673,
#   'id_str': '1466336340421660673',
#   'text': 'RT @squeal: Buried halfway in the YouTube Terms of Service update email is this tidbit: "if you are a publisher of news or current affairs…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 98,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336339893403649,
#   'id_str': '1466336339893403649',
#   'text': 'Coalition shelves bills on religious discrimination and federal Icac: https://t.co/AfQAZVf88s #auspol #australiapm',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336339784175618,
#   'id_str': '1466336339784175618',
#   'text': 'RT @Variety: .@bts_twt are boys with luv at SoFi Stadium ❤️ https://t.co/gedSqYvAiv https://t.co/mdMeFJuxE6',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 4347,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336339754987520,
#   'id_str': '1466336339754987520',
#   'text': "What should really 'unsettle' @MichealMartinTD &amp; @CMOIreland is that they've allowed the mass infection of children… https://t.co/auBvh09rlX",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336339620614145,
#   'id_str': '1466336339620614145',
#   'text': 'Thieves break into six cars in Erie https://t.co/jgDycivUwg via @YahooNews',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336338966245385,
#   'id_str': '1466336338966245385',
#   'text': 'RT @people4kam: NEWS: Symone Sanders is leaving the Biden-Harris Administration at the end of the year.\n\nThank you Symone for always defend…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 83,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336338249195520,
#   'id_str': '1466336338249195520',
#   'text': 'RT @HCOSC_Official: Now confirmed &amp; joining Jacob Greaves at our Meet @HullCity event hosted by @Brendon7375 and in partnership with @KCOMh…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336338043621378,
#   'id_str': '1466336338043621378',
#   'text': 'Vale trainer Joe Hall.\nhttps://t.co/0JEk7TBQ1w',
#   'source': 'Sprout Social',
#   'source_url': 'https://sproutsocial.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337984987136,
#   'id_str': '1466336337984987136',
#   'text': 'RT @Variety: BTS Tops Apple Music’s 2021 Most-Streamed Songs Chart https://t.co/B3hc95SDtX',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 6485,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337909403651,
#   'id_str': '1466336337909403651',
#   'text': 'The first confirmed U.S. case of the omicron coronavirus variant has been detected in San Francisco.\n https://t.co/varF05a4PT',
#   'source': 'Sprout Social',
#   'source_url': 'https://sproutsocial.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337703972864,
#   'id_str': '1466336337703972864',
#   'text': '#2 Borsa New York \nhttps://t.co/sLqNnKdABk\nhttps://t.co/oHJmROt1yn\nhttps://t.co/o5WOc52IvY\nhttps://t.co/2CBwRBBrNO… https://t.co/d8N6Mn0rUP',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'in_reply_to_status_id': 1455086822955130880,
#   'in_reply_to_status_id_str': '1455086822955130880',
#   'in_reply_to_user_id': 873918292909490176,
#   'in_reply_to_user_id_str': '873918292909490176',
#   'in_reply_to_screen_name': 'SorgentePas002',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337439698944,
#   'id_str': '1466336337439698944',
#   'text': 'RT @simplysimontfa: "the Prime Minister\'s official spokesman stressed the importance of collaboration" - that\'s something a French Presiden…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337372626948,
#   'id_str': '1466336337372626948',
#   'text': 'Our daily roundup of analyst and fund manager commentary on shares.\n\n ✒️ Michelle McGagh for Citywire @FundFanatic \n\nhttps://t.co/Sgr4bCyhUp',
#   'source': 'Loomly',
#   'source_url': 'https://www.loomly.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337179680770,
#   'id_str': '1466336337179680770',
#   'text': 'Boris Johnson had the opportunity to make a real impact during his recent speech at the #CBIConference, but he fail… https://t.co/gCRfxBuF8Y',
#   'source': 'Sprout Social',
#   'source_url': 'https://sproutsocial.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336337070473219,
#   'id_str': '1466336337070473219',
#   'text': 'RT @JYONI7144: [News pic] 2021 AAA (1)\n\n#이특 #LEETEUK https://t.co/iaWYkyasvh',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 219,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336336642772993,
#   'id_str': '1466336336642772993',
#   'text': '@mattletiss7 There are no real journalists any more and the news is all bought and paid for \U0001f972',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'in_reply_to_status_id': 1466327980867739649,
#   'in_reply_to_status_id_str': '1466327980867739649',
#   'in_reply_to_user_id': 239098915,
#   'in_reply_to_user_id_str': '239098915',
#   'in_reply_to_screen_name': 'mattletiss7',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336336445677575,
#   'id_str': '1466336336445677575',
#   'text': 'Fake news and misinformation have thrived on 🇪🇹Ethiopia by the western media, another one coming up by @CNN How man… https://t.co/8qpP7Nh7Lq',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336336223342593,
#   'id_str': '1466336336223342593',
#   'text': "RT @BBCNews: Linlithgow pub changes name over 'racist connotations' https://t.co/moezKrR7Ps",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 21,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336336143519747,
#   'id_str': '1466336336143519747',
#   'text': 'RT @AaronParnas: News flash: gerrymandering will not impact the Georgia, Florida, or Texas gubernatorial elections.',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 459,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335761977348,
#   'id_str': '1466336335761977348',
#   'text': 'The victim, Azeen Ahmed, was on his scooter when he is believed to have lost his balance while negotiating a bad pa… https://t.co/1guIFw8VM9',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'lang': 'en'},
#  {'id': 1466336335715831814,
#   'id_str': '1466336335715831814',
#   'text': 'Japan must reject dream of colonial do-over #CGTNFirstVoice https://t.co/hQ8zVwZ5Zr',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335644483586,
#   'id_str': '1466336335644483586',
#   'text': "Police said they are growing 'increasingly concerned' for the missing woman\nhttps://t.co/auf4YIeXyG",
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335606661121,
#   'id_str': '1466336335606661121',
#   'text': '#News 📰\nSe, Josta Ei Puhuta is back after ten years – New single and music video “Gehenna” is out now!\n➡️… https://t.co/nihpGiOiyK',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335602458627,
#   'id_str': '1466336335602458627',
#   'text': '#Archaeological finding traces Chinese tea #culture back to 400 BC\nhttps://t.co/4ueeFZ4kkb',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335581560836,
#   'id_str': '1466336335581560836',
#   'text': 'Council to provide financial support for Christmas festivities https://t.co/7o0iOsGEsy',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335568982019,
#   'id_str': '1466336335568982019',
#   'text': 'Predicted #nffc XI v #pufc as Steve Cooper faces left-back dilemma https://t.co/MQK3QmWbMk',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335548006400,
#   'id_str': '1466336335548006400',
#   'text': "Here's where to find the Christmas markets in #Kent this weekend... 🎄🎅\n\nhttps://t.co/IfOoEZf0R8",
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335547928588,
#   'id_str': '1466336335547928588',
#   'text': 'Check out the latest ep of Trial To Track from the team @thetrialfiles\nhttps://t.co/gFEqY707k5',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335526961153,
#   'id_str': '1466336335526961153',
#   'text': 'Check out our latest blog, written by our very own National Lead Practitioners - we delve into the world of Persona… https://t.co/2FQa6OOdEG',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335510196225,
#   'id_str': '1466336335510196225',
#   'text': 'RT @AmanKayamHai_: Shut for 31 Years, Yogi Adityanath Struggled for it as an MP since 1998 — Gorakhpur Fertilizer Plant to Finally be Re-op…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 10,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335497625601,
#   'id_str': '1466336335497625601',
#   'text': "Manchester United told how to beat Arsenal by isolating one 'main man' #MUFC\n\nhttps://t.co/4PZDmWGEp0 https://t.co/CoIvxwVakk",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335489232900,
#   'id_str': '1466336335489232900',
#   'text': 'Check out this amazing new bird robot designed by scientists at @Stanford that may help save humans one day:… https://t.co/8AtKb8chDH',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335468249094,
#   'id_str': '1466336335468249094',
#   'text': 'The US’s top medical adviser has warned there is still a lot to uncover about the latest Covid strain that has rece… https://t.co/K69jSC4U5A',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335451471878,
#   'id_str': '1466336335451471878',
#   'text': '4 travelers from S. Africa test negative for COVID in Negros Occidental https://t.co/UWYdw3W9d5',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335426424834,
#   'id_str': '1466336335426424834',
#   'text': 'Depth and breadth: How news organisations navigate trade-offs around building trust in news. Fascinating report fro… https://t.co/fMfSv3O7rT',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335409692676,
#   'id_str': '1466336335409692676',
#   'text': 'Turkey is in contact with Ukraine and Russia to ease tensions, Foreign Minister Mevlüt Çavuşoğlu said on Dec. 1, ad… https://t.co/fsXcvEDtuf',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335409684485,
#   'id_str': '1466336335409684485',
#   'text': 'Structures and Buildings Allowance qualifying expenditure https://t.co/pdSBNRTnrx https://t.co/FWRLnouoCp',
#   'source': 'Informanagement App',
#   'source_url': 'https://www.informanagement.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335409602561,
#   'id_str': '1466336335409602561',
#   'text': 'One day to go for #PurpleLights21! Go check out our media pack now https://t.co/dwx854L14C and get involved. It inc… https://t.co/D80YdcjtYJ',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335405350913,
#   'id_str': '1466336335405350913',
#   'text': 'Mysterious clouds could offer new clues on dark matter \n\n#Science #Astrophysics #Space #astronomy #Physics… https://t.co/TFAbgbeX3Z',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335397015554,
#   'id_str': '1466336335397015554',
#   'text': 'More Police For Safer Streets\n\nTHE number of crimes reported in Basingstoke in recent months has left residents con… https://t.co/OnyPljbg9J',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335392739329,
#   'id_str': '1466336335392739329',
#   'text': '.@HomesCrossman has submitted plans for nearly 100 new homes on the #B3167 Perry Street in #Tatworth near #Chard:… https://t.co/GSUHtcIXzp',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335384530945,
#   'id_str': '1466336335384530945',
#   'text': 'The 21st annual Lake Julian Festival of Lights held its opening night Wednesday, and there are several options for… https://t.co/d1MD2i4zCL',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335384522757,
#   'id_str': '1466336335384522757',
#   'text': "Here's where to find the Christmas markets in #Kent this weekend... 🎄🎅\n\nhttps://t.co/6XIgRSPsPp",
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335376044035,
#   'id_str': '1466336335376044035',
#   'text': 'Will the government increase basic salary or not? Find out! \n\n#SeventhPayCommission | #PayCommission \n\nhttps://t.co/sMAqFy9WWr',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335342542850,
#   'id_str': '1466336335342542850',
#   'text': 'Live updates after M56 crash as motorists advised to use alternative routes to avoid the area \n\nhttps://t.co/F38cQJeieq',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335334154246,
#   'id_str': '1466336335334154246',
#   'text': 'The accident occurred on Wednesday, December 1, at around 6:30 pm, according to gardai\n\nhttps://t.co/9Zdf9tYJjF',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335329959937,
#   'id_str': '1466336335329959937',
#   'text': 'Man arrested and taken to court for stealing Bible\nhttps://t.co/5cmBjPE9DA',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335325708299,
#   'id_str': '1466336335325708299',
#   'text': 'Forecast map for early today.        Get  Maps and Radars at  https://t.co/HNLPnb8GMF             \n#wx #weather… https://t.co/oeURq3krCt',
#   'source': 'Twitter for Advertisers.',
#   'source_url': 'https://ads-api.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335325708293,
#   'id_str': '1466336335325708293',
#   'text': "Here's where to find the Christmas markets in #Kent this weekend... 🎄🎅\n\nhttps://t.co/ZrODCN64XH",
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335300603906,
#   'id_str': '1466336335300603906',
#   'text': "It's a feeling that might be all too familiar to many, particularly to Gen Zs and millennials starting out in their… https://t.co/2dUc0st2yb",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336335296221185,
#   'id_str': '1466336335296221185',
#   'text': 'Over 14,000 AstraZeneca COVID-19 jabs expire in Negros Occidental - officials https://t.co/fJKD1ybfFe',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336334725980166,
#   'id_str': '1466336334725980166',
#   'text': "RT @BBCNews: 'How I got my dream job with a Tube station pitch' https://t.co/RrKGRkKLtO",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336334096777222,
#   'id_str': '1466336334096777222',
#   'text': 'RT @EA_DevCouncil: TPLF &amp; its Trust Fund Babies\' lobbying effort to push the fledgling "#TigrayGenocide" PR campaign has fallen flat on its…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 260,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336333929013248,
#   'id_str': '1466336333929013248',
#   'text': 'RT @ShaunTossell: NEWS: ⭐ WICKED MOVIE - NESSAROSE CASTING SEARCH ANNOUNCED ⭐\n\nVery cool to see inclusive casting happening ✨ X x x https:/…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 145,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336333689880581,
#   'id_str': '1466336333689880581',
#   'text': 'RT @NME: "It just took a long time to prepare," said EXO\'s Kai of his new mini-album \'Peaches\' https://t.co/S48nxAmcTs',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 424,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336333387878400,
#   'id_str': '1466336333387878400',
#   'text': "RT @BlocVaultAPP: 🚨This isn't a drill!🚨\n🐶This isn't a meme!🐶\n☄This is CHANGE!☄\nJoin me now and stay tuned for a chance to win a private sal…",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 2184,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336333207511048,
#   'id_str': '1466336333207511048',
#   'text': 'RT @XStreetDogs: Good News #XSDCommunity we have decided to give over 11,000 #Trustlines  a test #Airdrop of 100 #XSD. This is now ongoing…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 133,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336332750467081,
#   'id_str': '1466336332750467081',
#   'text': 'RT @larryandpaul: 💥 BREAKING NEWS: It’s the brand new #RealDailyBriefing, giving you an honest round-up from the UK Government this #Thursd…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 44,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336332217819139,
#   'id_str': '1466336332217819139',
#   'text': 'Smash-and-grab crime wave baffles congressional Democrats - https://t.co/1otSFtcKx9 - @washtimes',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336332100210691,
#   'id_str': '1466336332100210691',
#   'text': 'RT @htTweets: India on Dec 2 described the @UN Human Rights Office’s criticism of the arrest of rights activist #KhurramParvez and recent k…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336332020531206,
#   'id_str': '1466336332020531206',
#   'text': 'Jana Hocking on why men won’t date women over 35 https://t.co/FuWOQc7fSq',
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336331752251395,
#   'id_str': '1466336331752251395',
#   'text': 'More on current recruitment challenges, no breaking news or magic solutions here but some reflections on what we ar… https://t.co/lHQRZ8MDTb',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'quoted_status_id': 1466329573226913799,
#   'quoted_status_id_str': '1466329573226913799',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336330384818177,
#   'id_str': '1466336330384818177',
#   'text': 'RT @siphillipssport: “Brilliant from Kai. He could have shot, he was very unselfish and laid it for me and my aim was to get it on target.…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 72,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336330200268803,
#   'id_str': '1466336330200268803',
#   'text': 'RT @SolomonBerihu5: “Their aim is to leave no Tigrayan.” Amhara forces occupying western Tigray today, continue to commit ethnic cleansing.…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 16,
# ...
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336122380955655,
#   'id_str': '1466336122380955655',
#   'text': 'RT @JamesfWells: By my calculations this will cost £1.7 billion, minus any discount ($19.50 per dose)\n\n114 million additional doses mean NE…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 53,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336122150162435,
#   'id_str': '1466336122150162435',
#   'text': "RT @WorldOfTeyvat: Great news, those of you who haven't solved the Sudoku Puzzle yet, you can now easily solve it with this little guide I…",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 2392,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336121172856833,
#   'id_str': '1466336121172856833',
#   'text': 'RT @GarysBlues: Hunter Biden hasn’t missed the weekly news feed in years. Where’s the USA justice from this idiot!?🤔🙄✔️🇺🇸',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336121101635585,
#   'id_str': '1466336121101635585',
#   'text': '[BREAKING NEWS] A Free State police officer has allegedly shot his girlfriend nine times with his service pistol. T… https://t.co/vtJHwwwVZp',
#   'source': 'Hootsuite Inc.',
#   'source_url': 'https://www.hootsuite.com',
#   'retweet_count': 3,
#   'favorite_count': 3,
#   'lang': 'en'},
#  {'id': 1466336120975859715,
#   'id_str': '1466336120975859715',
#   'text': 'Texas woman accused of pointing gun at 6-month-old baby in viral video is arrested https://t.co/Z7lbmGrhGl -- #GunControlNow',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336120728428549,
#   'id_str': '1466336120728428549',
#   'text': "Seth Rogen has questions for Adele after 'One Night Only’ concert: ‘Why did you do that?’ - https://t.co/FiErGM7W5L… https://t.co/WiviuiJYkx",
#   'source': 'e-newusrss',
#   'source_url': 'https://e-news.us',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336119881187332,
#   'id_str': '1466336119881187332',
#   'text': 'RT @andmillsy: Final poll - one person guessed correctly on hole completion observations as latest RNS\nhttps://t.co/A3ZnVijEV7\nStill much m…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'quoted_status_id': 1466310319484162051,
#   'quoted_status_id_str': '1466310319484162051',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336119696637958,
#   'id_str': '1466336119696637958',
#   'text': 'Just found out my neighbours are creationists and believe that the bible is literally the word of God and therefore… https://t.co/owodasaM0W',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336119402999815,
#   'id_str': '1466336119402999815',
#   'text': 'RT @rumblevideo: BREAKING NEWS: Rumble to Combine with NASDAQ listed CFVI\n\nhttps://t.co/34opS1fNAu',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 232,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336119314808833,
#   'id_str': '1466336119314808833',
#   'text': 'RT @note_ddanahong: [BREAKING NEWS]\n\nOnly four members of #PENTAGON attends AAA red carpet because HONGSEOK still at the gym, YUTO still ca…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 276,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336118157176835,
#   'id_str': '1466336118157176835',
#   'text': 'RT @KimMangone: BREAKING NEWS: Stacey Abrams is running for Georgia Governor in 2022!\n\nRetweet this RIGHT NOW to spread the news and show y…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 6509,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336117926637570,
#   'id_str': '1466336117926637570',
#   'text': "RT @ClarkeMicah: Omicron cases are 'mild' and existing jabs should provide protection https://t.co/q66mrTfmQR via @MailOnline",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336117037228038,
#   'id_str': '1466336117037228038',
#   'text': 'Indian women football team lose 2-1 to Venezuela in four-nation tournament | Football\xa0News https://t.co/9Bv3jgEu7Z',
#   'source': 'WordPress.com',
#   'source_url': 'http://publicize.wp.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336117029052422,
#   'id_str': '1466336117029052422',
#   'text': 'RT @mattletiss7: Why isn’t this on the bbc news https://t.co/AvnbMV4oS6',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 288,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336116810952704,
#   'id_str': '1466336116810952704',
#   'text': '$SQ NEW ARTICLE : From Square to Block: Another tech company changes its name https://t.co/R2QoeWfQm4 Get all the l… https://t.co/bSqqp7XWeK',
#   'source': 'STCK.PR0',
#   'source_url': 'https://www.stck.pro',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336116085243904,
#   'id_str': '1466336116085243904',
#   'text': 'RT @MertiumFin: Is India Banning Cryptocurrency? How Can It Do That?: QuickTake\n\nNews Source: @crypto \n\nFor More Trending Crypto And Financ…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115904897031,
#   'id_str': '1466336115904897031',
#   'text': 'Breaking News\nNo cutting\nNo freezing\nA SPORTS HD\n100%Fast C-Line\nVideocon D2H 88E\nC-Line Available Hai\nTest Line Av… https://t.co/x3JjkEeLJf',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'lang': 'en'},
#  {'id': 1466336115686846469,
#   'id_str': '1466336115686846469',
#   'text': 'RT @lisakeb007: Covid: Trigger of rare blood clots with AstraZeneca jab found by scientists\n\nThis is why people wait for long term data…… h…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 10,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115628015621,
#   'id_str': '1466336115628015621',
#   'text': 'RT @craigmod: in other Japan news: a small island off the coast of Nagasaki will be opening in a special concession for Portuguese and Dutc…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 114,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115590410243,
#   'id_str': '1466336115590410243',
#   'text': 'RT @HIROOMI_3JSB_: 2021 ASIA ARTIST AWARDS\n\nhttps://t.co/PePDYMIIsk https://t.co/tFNR9DyXuu',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 807,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115468738562,
#   'id_str': '1466336115468738562',
#   'text': 'RT @jessphillips: What I was talking about on @peston in response to Matt Hancock. We called and called to help supply but I guess we are n…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 297,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115212922884,
#   'id_str': '1466336115212922884',
#   'text': 'RT @Sirius_EU: Today, Prof. Michelle Pace presents her work ‘The paradigm shift and migrant integration: Is something rotten in the state o…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115120615429,
#   'id_str': '1466336115120615429',
#   'text': 'RT @Queenofor: BREAKING NEWS...\n\n"Think Of How To Secure The Unconditional Release Of @MaziNnamdiKanu, Not How To Stop Sit-At-Home" ~ Rev.…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 124,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336115045056517,
#   'id_str': '1466336115045056517',
#   'text': 'RT @duty2warn: Dr Oz is running for Senate as a Republican. He was one of Trump’s Covid advisors who promoted hydroxychloroquine. He came t…',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 355,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336114600468483,
#   'id_str': '1466336114600468483',
#   'text': 'Major fashion brands linked to deforestation in the Amazon, report finds - Grist https://t.co/aUkuNGU7jN',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336114491408388,
#   'id_str': '1466336114491408388',
#   'text': 'Fake news and misinformation have thrived on 🇪🇹 by the western media, another one coming up by @CNN How many times… https://t.co/imud4OkF9n',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336113597956098,
#   'id_str': '1466336113597956098',
#   'text': "RT @haruharu_w_bts: 🐹i heard you burped and came here! when there's other news i'll come again!\n\n@BTS_twt",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 3593,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336112486625286,
#   'id_str': '1466336112486625286',
#   'text': 'Manchester City’s Bernardo Silva proves Guardiola avoided the biggest transfer setback of his career:\n\n🗣️ "The most… https://t.co/Vz7zL2OAxj',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111622451202,
#   'id_str': '1466336111622451202',
#   'text': "@FrontTron Korean reporters had asked Qualcomm's top executives for clarification and they have confirmed that it's… https://t.co/DKNPQmLhZk",
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'in_reply_to_status_id': 1465944846863007751,
#   'in_reply_to_status_id_str': '1465944846863007751',
#   'in_reply_to_user_id': 870664567587721217,
#   'in_reply_to_user_id_str': '870664567587721217',
#   'in_reply_to_screen_name': 'FrontTron',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111370850304,
#   'id_str': '1466336111370850304',
#   'text': "RT @EssexPR: “Face masks DO harm kids' development, landmark study shows” https://t.co/jU7DybeZhG via @MailOnline",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 330,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111349936132,
#   'id_str': '1466336111349936132',
#   'text': '7 more test positive, UP has 92 active Covid cases | Kanpur\xa0News https://t.co/9f4Q3PRwEg',
#   'source': 'WordPress.com',
#   'source_url': 'http://publicize.wp.com/',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111161077760,
#   'id_str': '1466336111161077760',
#   'text': "RT @PoliticalShort: An Illinois family whose loved one was hospitalized with COVID-19 and put on a ventilator says he's now home and doing…",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 3225,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111056330754,
#   'id_str': '1466336111056330754',
#   'text': "RT @DickMackintosh: Last-minute amendments to the Police, Crime, Courts and Sentencing Bill will impose up to six months' jail on protester…",
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'retweet_count': 22,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336111031029770,
#   'id_str': '1466336111031029770',
#   'text': '@bbchartpredicts @Adele @taylorswift13 @Alanis @Carole_King ughh her power scares me sometimes\n\nhttps://t.co/IoUvfHZNoq',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'in_reply_to_status_id': 1466247103135502339,
#   'in_reply_to_status_id_str': '1466247103135502339',
#   'in_reply_to_user_id': 1343666943610548224,
#   'in_reply_to_user_id_str': '1343666943610548224',
#   'in_reply_to_screen_name': 'bbchartpredicts',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336110485905409,
#   'id_str': '1466336110485905409',
#   'text': "RT @Loriagne2: Families' fury at Johnson's 'sickening' boozy lockdown Christmas parties scandal https://t.co/Hc5WQKCH8G",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 14,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336110284468231,
#   'id_str': '1466336110284468231',
#   'text': "RT @miiniyoongs: 🐹 i'll come again if i hear any more good news!",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 1772,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336110221701123,
#   'id_str': '1466336110221701123',
#   'text': 'RT @fxsignalsai: Instrument: WTICO_USD\n        Margin Used: 2.6%\n        Entry Price: $66.789\n        Direction: SHORT\n        Take Profit:…',
#   'source': 'tradersreport Twitter-Bot',
#   'source_url': 'https://www.tradersreport.de',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336110041305088,
#   'id_str': '1466336110041305088',
#   'text': 'RT @katrinatulloch: Eight days after Anthony Broadwater was exonerated from this rape conviction, Alice Sebold apologized, saying: "I will…',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 806,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336109856755724,
#   'id_str': '1466336109856755724',
#   'text': "RT @garethicke: It's never meant to end. \n\nA FOURTH and FIFTH jab to fight Covid : UK orders 114m extra vaccine doses - enough to keep coun…",
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 130,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336109286367237,
#   'id_str': '1466336109286367237',
#   'text': 'RT @wsvn: Man who had open-heart surgery wins a $1 million lottery prize after the ticket came in a get-well card\n\nhttps://t.co/XZEGSp9oP7',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 35,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336108359270400,
#   'id_str': '1466336108359270400',
#   'text': 'RT @4dynastyrich: This @Picassol_NFT is a Wall Street secret.\nElon Musk, seriously..?\n\nTWO articles exposed all..\nhttps://t.co/jliE1c87sM…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 398,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336107721891840,
#   'id_str': '1466336107721891840',
#   'text': 'RT @WorcsTS: #AllergyAlert Nutrisure Ltd recalls Naturya Hemp Protein Powder because of undeclared gluten\nBatch code - W02135, Best beforee…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'id': 1466336107688304640,
#   'id_str': '1466336107688304640',
#   'text': "Oh dear.\n\nUnless of course you're a govt crony.\n\nIn which case, \non your knee, tongues presented for ministerial or… https://t.co/wbh5A1y80P",
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'}]

# %%
df = pd.DataFrame(tweets_data,columns=header_cols)

# %%
df
# Out:
#      retweet_count lang               id_str  \
# 0              318   en  1466336359501598721
# 1                2   en  1466336358700437514
# 2                2   en  1466336358478323714
# 3                3   en  1466336357337354240
# 4                0   en  1466336357224267778
# ..             ...  ...                  ...
# 795            130   en  1466336109856755724
# 796             35   en  1466336109286367237
# 797            398   en  1466336108359270400
# 798              1   en  1466336107721891840
# 799              0   en  1466336107688304640
#
#                                                   text  \
# 0    RT @LaysPhilippines: Great news! Lay’s is now ...
# 1    RT @livemint: India to initially introduce #Zy...
# 2    RT @HallamHRI: 🗣Join us for our next SHU inter...
# 3    RT @thetrialfiles: TRIAL TO TRACK |\n\nIt’s he...
# 4    Triple-jabbed Israeli doctor believes he caugh...
# ..                                                 ...
# 795  RT @garethicke: It's never meant to end. \n\nA...
# 796  RT @wsvn: Man who had open-heart surgery wins ...
# 797  RT @4dynastyrich: This @Picassol_NFT is a Wall...
# 798  RT @WorcsTS: #AllergyAlert Nutrisure Ltd recal...
# 799  Oh dear.\n\nUnless of course you're a govt cro...
#
#     in_reply_to_screen_name               source in_reply_to_status_id_str  \
# 0                       NaN  Twitter for Android                       NaN
# 1                       NaN  Twitter for Android                       NaN
# 2                       NaN      Twitter Web App                       NaN
# 3                       NaN   Twitter for iPhone                       NaN
# 4                       NaN           SocialFlow                       NaN
# ..                      ...                  ...                       ...
# 795                     NaN   Twitter for iPhone                       NaN
# 796                     NaN   Twitter for iPhone                       NaN
# 797                     NaN      Twitter Web App                       NaN
# 798                     NaN      Twitter Web App                       NaN
# 799                     NaN  Twitter for Android                       NaN
#
#      quoted_status_id                   id in_reply_to_user_id_str  \
# 0                 NaN  1466336359501598721                     NaN
# 1                 NaN  1466336358700437514                     NaN
# 2                 NaN  1466336358478323714                     NaN
# 3                 NaN  1466336357337354240                     NaN
# 4                 NaN  1466336357224267778                     NaN
# ..                ...                  ...                     ...
# 795               NaN  1466336109856755724                     NaN
# 796               NaN  1466336109286367237                     NaN
# 797               NaN  1466336108359270400                     NaN
# 798               NaN  1466336107721891840                     NaN
# 799               NaN  1466336107688304640                     NaN
#
#      in_reply_to_user_id  favorite_count  in_reply_to_status_id  \
# 0                    NaN               0                    NaN
# 1                    NaN               0                    NaN
# 2                    NaN               0                    NaN
# 3                    NaN               0                    NaN
# 4                    NaN               0                    NaN
# ..                   ...             ...                    ...
# 795                  NaN               0                    NaN
# 796                  NaN               0                    NaN
# 797                  NaN               0                    NaN
# 798                  NaN               0                    NaN
# 799                  NaN               0                    NaN
#
#     quoted_status_id_str                           source_url
# 0                    NaN  http://twitter.com/download/android
# 1                    NaN  http://twitter.com/download/android
# 2                    NaN           https://mobile.twitter.com
# 3                    NaN   http://twitter.com/download/iphone
# 4                    NaN            http://www.socialflow.com
# ..                   ...                                  ...
# 795                  NaN   http://twitter.com/download/iphone
# 796                  NaN   http://twitter.com/download/iphone
# 797                  NaN           https://mobile.twitter.com
# 798                  NaN           https://mobile.twitter.com
# 799                  NaN  http://twitter.com/download/android
#
# [800 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# retweet_count                  0
# lang                           0
# id_str                         0
# text                           0
# in_reply_to_screen_name      740
# source                         0
# in_reply_to_status_id_str    742
# quoted_status_id             771
# id                             0
# in_reply_to_user_id_str      740
# in_reply_to_user_id          740
# favorite_count                 0
# in_reply_to_status_id        742
# quoted_status_id_str         771
# source_url                     0
# dtype: int64

# %%
df
# Out:
#      retweet_count lang               id_str  \
# 0              318   en  1466336359501598721
# 1                2   en  1466336358700437514
# 2                2   en  1466336358478323714
# 3                3   en  1466336357337354240
# 4                0   en  1466336357224267778
# ..             ...  ...                  ...
# 795            130   en  1466336109856755724
# 796             35   en  1466336109286367237
# 797            398   en  1466336108359270400
# 798              1   en  1466336107721891840
# 799              0   en  1466336107688304640
#
#                                                   text  \
# 0    RT @LaysPhilippines: Great news! Lay’s is now ...
# 1    RT @livemint: India to initially introduce #Zy...
# 2    RT @HallamHRI: 🗣Join us for our next SHU inter...
# 3    RT @thetrialfiles: TRIAL TO TRACK |\n\nIt’s he...
# 4    Triple-jabbed Israeli doctor believes he caugh...
# ..                                                 ...
# 795  RT @garethicke: It's never meant to end. \n\nA...
# 796  RT @wsvn: Man who had open-heart surgery wins ...
# 797  RT @4dynastyrich: This @Picassol_NFT is a Wall...
# 798  RT @WorcsTS: #AllergyAlert Nutrisure Ltd recal...
# 799  Oh dear.\n\nUnless of course you're a govt cro...
#
#     in_reply_to_screen_name               source in_reply_to_status_id_str  \
# 0                       NaN  Twitter for Android                       NaN
# 1                       NaN  Twitter for Android                       NaN
# 2                       NaN      Twitter Web App                       NaN
# 3                       NaN   Twitter for iPhone                       NaN
# 4                       NaN           SocialFlow                       NaN
# ..                      ...                  ...                       ...
# 795                     NaN   Twitter for iPhone                       NaN
# 796                     NaN   Twitter for iPhone                       NaN
# 797                     NaN      Twitter Web App                       NaN
# 798                     NaN      Twitter Web App                       NaN
# 799                     NaN  Twitter for Android                       NaN
#
#      quoted_status_id                   id in_reply_to_user_id_str  \
# 0                 NaN  1466336359501598721                     NaN
# 1                 NaN  1466336358700437514                     NaN
# 2                 NaN  1466336358478323714                     NaN
# 3                 NaN  1466336357337354240                     NaN
# 4                 NaN  1466336357224267778                     NaN
# ..                ...                  ...                     ...
# 795               NaN  1466336109856755724                     NaN
# 796               NaN  1466336109286367237                     NaN
# 797               NaN  1466336108359270400                     NaN
# 798               NaN  1466336107721891840                     NaN
# 799               NaN  1466336107688304640                     NaN
#
#      in_reply_to_user_id  favorite_count  in_reply_to_status_id  \
# 0                    NaN               0                    NaN
# 1                    NaN               0                    NaN
# 2                    NaN               0                    NaN
# 3                    NaN               0                    NaN
# 4                    NaN               0                    NaN
# ..                   ...             ...                    ...
# 795                  NaN               0                    NaN
# 796                  NaN               0                    NaN
# 797                  NaN               0                    NaN
# 798                  NaN               0                    NaN
# 799                  NaN               0                    NaN
#
#     quoted_status_id_str                           source_url
# 0                    NaN  http://twitter.com/download/android
# 1                    NaN  http://twitter.com/download/android
# 2                    NaN           https://mobile.twitter.com
# 3                    NaN   http://twitter.com/download/iphone
# 4                    NaN            http://www.socialflow.com
# ..                   ...                                  ...
# 795                  NaN   http://twitter.com/download/iphone
# 796                  NaN   http://twitter.com/download/iphone
# 797                  NaN           https://mobile.twitter.com
# 798                  NaN           https://mobile.twitter.com
# 799                  NaN  http://twitter.com/download/android
#
# [800 rows x 15 columns]

# %%
df.to_json('sentiment_anlysis_twitter2.json')

# %%
df.isnull().sum()
# Out:
# retweet_count                  0
# lang                           0
# id_str                         0
# text                           0
# in_reply_to_screen_name      740
# source                         0
# in_reply_to_status_id_str    742
# quoted_status_id             771
# id                             0
# in_reply_to_user_id_str      740
# in_reply_to_user_id          740
# favorite_count                 0
# in_reply_to_status_id        742
# quoted_status_id_str         771
# source_url                     0
# dtype: int64

# %%
df.index[0]
# Out:
# 0

# %%
tweets_data[50]
# Out:
# {'id': 1466336346033774595,
#  'id_str': '1466336346033774595',
#  'text': 'Bosses cancel Christmas parties and tell workers to stay home\nhttps://t.co/owjs7WitGi https://t.co/oCkBcFGtUY',
#  'source': 'Hootsuite Inc.',
#  'source_url': 'https://www.hootsuite.com',
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'lang': 'en'}

# %%
df
# Out:
#      retweet_count lang               id_str  \
# 0              318   en  1466336359501598721
# 1                2   en  1466336358700437514
# 2                2   en  1466336358478323714
# 3                3   en  1466336357337354240
# 4                0   en  1466336357224267778
# ..             ...  ...                  ...
# 795            130   en  1466336109856755724
# 796             35   en  1466336109286367237
# 797            398   en  1466336108359270400
# 798              1   en  1466336107721891840
# 799              0   en  1466336107688304640
#
#                                                   text  \
# 0    RT @LaysPhilippines: Great news! Lay’s is now ...
# 1    RT @livemint: India to initially introduce #Zy...
# 2    RT @HallamHRI: 🗣Join us for our next SHU inter...
# 3    RT @thetrialfiles: TRIAL TO TRACK |\n\nIt’s he...
# 4    Triple-jabbed Israeli doctor believes he caugh...
# ..                                                 ...
# 795  RT @garethicke: It's never meant to end. \n\nA...
# 796  RT @wsvn: Man who had open-heart surgery wins ...
# 797  RT @4dynastyrich: This @Picassol_NFT is a Wall...
# 798  RT @WorcsTS: #AllergyAlert Nutrisure Ltd recal...
# 799  Oh dear.\n\nUnless of course you're a govt cro...
#
#     in_reply_to_screen_name               source in_reply_to_status_id_str  \
# 0                       NaN  Twitter for Android                       NaN
# 1                       NaN  Twitter for Android                       NaN
# 2                       NaN      Twitter Web App                       NaN
# 3                       NaN   Twitter for iPhone                       NaN
# 4                       NaN           SocialFlow                       NaN
# ..                      ...                  ...                       ...
# 795                     NaN   Twitter for iPhone                       NaN
# 796                     NaN   Twitter for iPhone                       NaN
# 797                     NaN      Twitter Web App                       NaN
# 798                     NaN      Twitter Web App                       NaN
# 799                     NaN  Twitter for Android                       NaN
#
#      quoted_status_id                   id in_reply_to_user_id_str  \
# 0                 NaN  1466336359501598721                     NaN
# 1                 NaN  1466336358700437514                     NaN
# 2                 NaN  1466336358478323714                     NaN
# 3                 NaN  1466336357337354240                     NaN
# 4                 NaN  1466336357224267778                     NaN
# ..                ...                  ...                     ...
# 795               NaN  1466336109856755724                     NaN
# 796               NaN  1466336109286367237                     NaN
# 797               NaN  1466336108359270400                     NaN
# 798               NaN  1466336107721891840                     NaN
# 799               NaN  1466336107688304640                     NaN
#
#      in_reply_to_user_id  favorite_count  in_reply_to_status_id  \
# 0                    NaN               0                    NaN
# 1                    NaN               0                    NaN
# 2                    NaN               0                    NaN
# 3                    NaN               0                    NaN
# 4                    NaN               0                    NaN
# ..                   ...             ...                    ...
# 795                  NaN               0                    NaN
# 796                  NaN               0                    NaN
# 797                  NaN               0                    NaN
# 798                  NaN               0                    NaN
# 799                  NaN               0                    NaN
#
#     quoted_status_id_str                           source_url
# 0                    NaN  http://twitter.com/download/android
# 1                    NaN  http://twitter.com/download/android
# 2                    NaN           https://mobile.twitter.com
# 3                    NaN   http://twitter.com/download/iphone
# 4                    NaN            http://www.socialflow.com
# ..                   ...                                  ...
# 795                  NaN   http://twitter.com/download/iphone
# 796                  NaN   http://twitter.com/download/iphone
# 797                  NaN           https://mobile.twitter.com
# 798                  NaN           https://mobile.twitter.com
# 799                  NaN  http://twitter.com/download/android
#
# [800 rows x 15 columns]

# %%
df['text'][0]
# Out:
# 'RT @LaysPhilippines: Great news! Lay’s is now “100% Plastic Neutral”!*\n\nThis means for every pack you buy an equal amount of plastic waste…'

# %%
df.columns[:15][0]
# Out:
# 'retweet_count'

# %%
df.loc[:15]
# Out:
#     retweet_count lang               id_str  \
# 0             318   en  1466336359501598721
# 1               2   en  1466336358700437514
# 2               2   en  1466336358478323714
# 3               3   en  1466336357337354240
# 4               0   en  1466336357224267778
# 5               1   en  1466336357094207488
# 6              18   en  1466336356901265409
# 7              13   en  1466336356699979778
# 8               8   en  1466336356301295617
# 9               0   en  1466336356146290696
# 10             34   en  1466336356074811392
# 11              0   en  1466336355982606337
# 12              1   en  1466336355600977925
# 13              0   en  1466336355424739329
# 14              0   en  1466336355085127683
# 15              0   en  1466336355030552578
#
#                                                  text in_reply_to_screen_name  \
# 0   RT @LaysPhilippines: Great news! Lay’s is now ...                     NaN
# 1   RT @livemint: India to initially introduce #Zy...                     NaN
# 2   RT @HallamHRI: 🗣Join us for our next SHU inter...                     NaN
# 3   RT @thetrialfiles: TRIAL TO TRACK |\n\nIt’s he...                     NaN
# 4   Triple-jabbed Israeli doctor believes he caugh...                     NaN
# 5   RT @financialombuds: We’ve published today an ...                     NaN
# 6   RT @TheSinanKose: Tell me again how I'm suppos...                     NaN
# 7   RT @Jingo82943256: Breaking News\n\n"Think Of ...                     NaN
# 8   RT @lili4lisaa: I hope 2022 is a year full of ...                     NaN
# 9   The 26-year-old died at the scene and his litt...                     NaN
# 10  RT @KenRoth: On Mar 14, Myanmar security force...                     NaN
# 11  QSO Today Virtual Ham Expo - Call for Speakers...                     NaN
# 12  RT @BDliveSA: BREAKING NEWS: Court orders fres...                     NaN
# 13  What channel is Cowboys vs. Saints on today? S...                     NaN
# 14  @CryptoZyte_News @trace_network During the 202...         CryptoZyte_News
# 15  Chicago drops its lawsuit against police union...                     NaN
#
#                  source in_reply_to_status_id_str  quoted_status_id  \
# 0   Twitter for Android                       NaN               NaN
# 1   Twitter for Android                       NaN               NaN
# 2       Twitter Web App                       NaN               NaN
# 3    Twitter for iPhone                       NaN               NaN
# 4            SocialFlow                       NaN               NaN
# 5       Twitter Web App                       NaN               NaN
# 6   Twitter for Android                       NaN      1.466313e+18
# 7   Twitter for Android                       NaN               NaN
# 8   Twitter for Android                       NaN               NaN
# 9             TweetDeck                       NaN               NaN
# 10  Twitter for Android                       NaN               NaN
# 11              dlvr.it                       NaN               NaN
# 12  Twitter for Android                       NaN               NaN
# 13              dlvr.it                       NaN               NaN
# 14  Twitter for Android       1466334704475336708               NaN
# 15           SocialFlow                       NaN               NaN
#
#                      id in_reply_to_user_id_str  in_reply_to_user_id  \
# 0   1466336359501598721                     NaN                  NaN
# 1   1466336358700437514                     NaN                  NaN
# 2   1466336358478323714                     NaN                  NaN
# 3   1466336357337354240                     NaN                  NaN
# 4   1466336357224267778                     NaN                  NaN
# 5   1466336357094207488                     NaN                  NaN
# 6   1466336356901265409                     NaN                  NaN
# 7   1466336356699979778                     NaN                  NaN
# 8   1466336356301295617                     NaN                  NaN
# 9   1466336356146290696                     NaN                  NaN
# 10  1466336356074811392                     NaN                  NaN
# 11  1466336355982606337                     NaN                  NaN
# 12  1466336355600977925                     NaN                  NaN
# 13  1466336355424739329                     NaN                  NaN
# 14  1466336355085127683     1321953728199487488         1.321954e+18
# 15  1466336355030552578                     NaN                  NaN
#
#     favorite_count  in_reply_to_status_id quoted_status_id_str  \
# 0                0                    NaN                  NaN
# 1                0                    NaN                  NaN
# 2                0                    NaN                  NaN
# 3                0                    NaN                  NaN
# 4                0                    NaN                  NaN
# 5                0                    NaN                  NaN
# 6                0                    NaN  1466312656667779078
# 7                0                    NaN                  NaN
# 8                0                    NaN                  NaN
# 9                0                    NaN                  NaN
# 10               0                    NaN                  NaN
# 11               0                    NaN                  NaN
# 12               0                    NaN                  NaN
# 13               0                    NaN                  NaN
# 14               0           1.466335e+18                  NaN
# 15               0                    NaN                  NaN
#
#                                       source_url
# 0            http://twitter.com/download/android
# 1            http://twitter.com/download/android
# 2                     https://mobile.twitter.com
# 3             http://twitter.com/download/iphone
# 4                      http://www.socialflow.com
# 5                     https://mobile.twitter.com
# 6            http://twitter.com/download/android
# 7            http://twitter.com/download/android
# 8            http://twitter.com/download/android
# 9   https://about.twitter.com/products/tweetdeck
# 10           http://twitter.com/download/android
# 11                           https://dlvrit.com/
# 12           http://twitter.com/download/android
# 13                           https://dlvrit.com/
# 14           http://twitter.com/download/android
# 15                     http://www.socialflow.com
